# %%
# Verilen linkteki klasörü indirip Google Drive'a kaydedin 
# link: https://github.com/ozgurkan/MaskRCNN
# Daha sonra klasörü drive adresinize kopyalayın
# Son olarak aşağıdaki kodu çalıştırıp klasörü yüklediğiniz drive adresine bağlanın.

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# !mkdir mask_rcnn_train

# %%
cd /content/drive/My Drive/mask_rcnn_custom_train

# %%
from distutils.dir_util import copy_tree
copy_tree("/content/drive/My Drive/mask_rcnn_custom_train", "/content/mask_rcnn_train/")

# %%
# %tensorflow_version 2.x
# !pip uninstall -y tensorflow
# !pip install tensorflow-gpu==1.14.0
# !pip install Keras==2.2.4
# !pip install mrcnn

# %%
cd /content/mask_rcnn_train

# %%
# !pip install mmcv

# %%
cd /content/mask_rcnn_train

# %%
# !python xml2coco_train.py

# %%
# !python xml2coco_val.py

# %%
pip install labelme

# %%
# !git clone https://github.com/matterport/Mask_RCNN.git

# %%
# !python3 /content/mask_rcnn_train/train.py train --dataset=/content/mask_rcnn_train/dataset --weights=coco

# %%
# !pip uninstall tensorboard-plugin-wit

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/drive/My\ Drive/logs

# %%
# !pip install tensorboard

# %%
# !python /content/mask_rcnn_train/test_images.py --i /content/test/AliKeyifli-1.jpg --o /content

# %%
# !python /content/mask_rcnn_train/video_detection.py -v /content/Video_5.avi -sp pedestrian_detection.avi
